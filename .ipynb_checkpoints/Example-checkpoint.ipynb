# %% [markdown]
# # Jupyter Warm-UP

# %% [markdown]
# ## Define Variable

# %%
x = 15

# %%
x
# Out:
# 15

# %% [markdown]
# ## Hyperlinks

# %% [markdown]
# [Jupyter Website](https://jupyter.org)

# %% [markdown]
# ![micro-services-book.png](attachment:micro-services-book.png)
